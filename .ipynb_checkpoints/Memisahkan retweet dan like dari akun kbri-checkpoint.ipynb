# %%
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 999

# %% [markdown]
# ## Import Datsets

# %%
stock_file = sorted(glob("Gabungan/data_*.csv"))
stock_file
# Out:
# ['Gabungan\\data_1.csv',
#  'Gabungan\\data_10.csv',
#  'Gabungan\\data_11.csv',
#  'Gabungan\\data_12.csv',
#  'Gabungan\\data_13.csv',
#  'Gabungan\\data_14.csv',
#  'Gabungan\\data_15.csv',
#  'Gabungan\\data_16.csv',
#  'Gabungan\\data_17.csv',
#  'Gabungan\\data_18.csv',
#  'Gabungan\\data_19.csv',
#  'Gabungan\\data_2.csv',
#  'Gabungan\\data_20.csv',
#  'Gabungan\\data_21.csv',
#  'Gabungan\\data_22.csv',
#  'Gabungan\\data_23.csv',
#  'Gabungan\\data_24.csv',
#  'Gabungan\\data_25.csv',
#  'Gabungan\\data_26.csv',
#  'Gabungan\\data_27.csv',
#  'Gabungan\\data_28.csv',
#  'Gabungan\\data_29.csv',
#  'Gabungan\\data_3.csv',
#  'Gabungan\\data_30.csv',
#  'Gabungan\\data_31.csv',
#  'Gabungan\\data_32.csv',
#  'Gabungan\\data_33.csv',
#  'Gabungan\\data_34.csv',
#  'Gabungan\\data_35.csv',
#  'Gabungan\\data_36.csv',
#  'Gabungan\\data_37.csv',
#  'Gabungan\\data_38.csv',
#  'Gabungan\\data_39.csv',
#  'Gabungan\\data_4.csv',
#  'Gabungan\\data_40.csv',
#  'Gabungan\\data_41.csv',
#  'Gabungan\\data_42.csv',
#  'Gabungan\\data_43.csv',
#  'Gabungan\\data_44.csv',
#  'Gabungan\\data_45.csv',
#  'Gabungan\\data_46.csv',
#  'Gabungan\\data_47.csv',
#  'Gabungan\\data_48.csv',
#  'Gabungan\\data_49.csv',
#  'Gabungan\\data_5.csv',
#  'Gabungan\\data_50.csv',
#  'Gabungan\\data_6.csv',
#  'Gabungan\\data_7.csv',
#  'Gabungan\\data_8.csv',
#  'Gabungan\\data_9.csv']

# %%
df = pd.concat((pd.read_csv(file, sep=",", encoding='cp1252').assign(filename = file) for file in stock_file), ignore_index=True)
df.head()
# Out:
#    Unnamed: 0     user_id            status_id           created_at  \
# 0           1  3314172242  1295616014093180928  2020-08-18 06:58:23
# 1           2  3314172242  1295246886689861633  2020-08-17 06:31:36
# 2           3  3314172242  1295235223177711616  2020-08-17 05:45:16
# 3           4  3314172242  1295153779453521920  2020-08-17 00:21:38
# 4           5  3314172242  1294987353518350336  2020-08-16 13:20:19
#
#       screen_name                                               text  \
# 0  IndonesiaHanoi  Before the COVID-19 pandemic, Indonesians used...
# 1  IndonesiaHanoi  Presiden Jokowi Berbaju Adat NTT Saat Pimpin U...
# 2  IndonesiaHanoi  Kita menikmati arti kemerdekaan, karena kita m...
# 3  IndonesiaHanoi  Pada 17/08, pukul 10.17 WIB, mari hentikan akt...
# 4  IndonesiaHanoi  Get an adrenaline rush! Plunge into the mesmer...
#
#                 source  display_text_width  reply_to_status_id  \
# 0  Twitter for Android                 140                 NaN
# 1      Twitter Web App                 138                 NaN
# 2      Twitter Web App                 140                 NaN
# 3  Twitter for Android                 275                 NaN
# 4  Twitter for Android                 140                 NaN
#
#    reply_to_user_id reply_to_screen_name  is_quote  is_retweet  \
# 0               NaN                  NaN     False        True
# 1               NaN                  NaN     False        True
# 2               NaN                  NaN     False        True
# 3               NaN                  NaN     False       False
# 4               NaN                  NaN     False        True
#
#    favorite_count  retweet_count  quote_count  reply_count  \
# 0               0              7          NaN          NaN
# 1               0             26          NaN          NaN
# 2               0           8592          NaN          NaN
# 3               2              0          NaN          NaN
# 4               0            113          NaN          NaN
#
#                                         hashtags  symbols  \
# 0                                            NaN      NaN
# 1                                            NaN      NaN
# 2                                            NaN      NaN
# 3  c("IniDiplomasi", "IndonesianWay", "hutri75")      NaN
# 4                                            NaN      NaN
#
#                        urls_url                urls_t.co  \
# 0                           NaN                      NaN
# 1  setneg.go.id/baca/index/pre…  https://t.co/Uezyg3Foec
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
#                                    urls_expanded_url  \
# 0                                                NaN
# 1  https://www.setneg.go.id/baca/index/presiden_j...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            media_url               media_t.co  \
# 0                                                NaN                      NaN
# 1     http://pbs.twimg.com/media/EfmjDWNUYAAO2Tk.jpg  https://t.co/h4t7xmmxAK
# 2                                                NaN                      NaN
# 3  http://pbs.twimg.com/ext_tw_video_thumb/129515...  https://t.co/P47LjqWipp
# 4                                                NaN                      NaN
#
#                                   media_expanded_url media_type  \
# 0                                                NaN        NaN
# 1  https://twitter.com/KemensetnegRI/status/12952...      photo
# 2                                                NaN        NaN
# 3  https://twitter.com/IndonesiaHanoi/status/1295...      photo
# 4                                                NaN        NaN
#
#                                        ext_media_url  \
# 0                                                NaN
# 1  c("http://pbs.twimg.com/media/EfmjDWNUYAAO2Tk....
# 2                                                NaN
# 3  http://pbs.twimg.com/ext_tw_video_thumb/129515...
# 4                                                NaN
#
#                                       ext_media_t.co  \
# 0                                                NaN
# 1  c("https://t.co/h4t7xmmxAK", "https://t.co/h4t...
# 2                                                NaN
# 3                            https://t.co/P47LjqWipp
# 4                                                NaN
#
#                               ext_media_expanded_url  ext_media_type  \
# 0                                                NaN             NaN
# 1  c("https://twitter.com/KemensetnegRI/status/12...             NaN
# 2                                                NaN             NaN
# 3  https://twitter.com/IndonesiaHanoi/status/1295...             NaN
# 4                                                NaN             NaN
#
#   mentions_user_id mentions_screen_name lang  quoted_status_id quoted_text  \
# 0         74377194            indtravel   en               NaN         NaN
# 1       3522129133        KemensetnegRI   in               NaN         NaN
# 2        366987179               jokowi   in               NaN         NaN
# 3              NaN                  NaN   in               NaN         NaN
# 4         74377194            indtravel   en               NaN         NaN
#
#   quoted_created_at quoted_source  quoted_favorite_count  \
# 0               NaN           NaN                    NaN
# 1               NaN           NaN                    NaN
# 2               NaN           NaN                    NaN
# 3               NaN           NaN                    NaN
# 4               NaN           NaN                    NaN
#
#    quoted_retweet_count  quoted_user_id quoted_screen_name quoted_name  \
# 0                   NaN             NaN                NaN         NaN
# 1                   NaN             NaN                NaN         NaN
# 2                   NaN             NaN                NaN         NaN
# 3                   NaN             NaN                NaN         NaN
# 4                   NaN             NaN                NaN         NaN
#
#    quoted_followers_count  quoted_friends_count  quoted_statuses_count  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   quoted_location quoted_description quoted_verified  retweet_status_id  \
# 0             NaN                NaN             NaN       1.295325e+18
# 1             NaN                NaN             NaN       1.295246e+18
# 2             NaN                NaN             NaN       1.295163e+18
# 3             NaN                NaN             NaN                NaN
# 4             NaN                NaN             NaN       1.294966e+18
#
#                                         retweet_text   retweet_created_at  \
# 0  Before the COVID-19 pandemic, Indonesians used...  2020-08-17 11:43:15
# 1  Presiden Jokowi Berbaju Adat NTT Saat Pimpin U...  2020-08-17 06:27:22
# 2  Kita menikmati arti kemerdekaan, karena kita m...  2020-08-17 01:00:01
# 3                                                NaN                  NaN
# 4  Get an adrenaline rush! Plunge into the mesmer...  2020-08-16 11:56:52
#
#        retweet_source  retweet_favorite_count  retweet_retweet_count  \
# 0  Twitter for iPhone                    14.0                    7.0
# 1  Twitter for iPhone                   128.0                   26.0
# 2     Twitter Web App                 28723.0                 8592.0
# 3                 NaN                     NaN                    NaN
# 4  Twitter for iPhone                   261.0                  113.0
#
#    retweet_user_id retweet_screen_name        retweet_name  \
# 0     7.437719e+07           indtravel    Indonesia.Travel
# 1     3.522129e+09       KemensetnegRI  Sekretariat Negara
# 2     3.669872e+08              jokowi         Joko Widodo
# 3              NaN                 NaN                 NaN
# 4     7.437719e+07           indtravel    Indonesia.Travel
#
#    retweet_followers_count  retweet_friends_count  retweet_statuses_count  \
# 0                1325495.0                  411.0                 23494.0
# 1                 454302.0                  171.0                 21922.0
# 2               14215854.0                   59.0                  2717.0
# 3                      NaN                    NaN                     NaN
# 4                1325495.0                  411.0                 23494.0
#
#              retweet_location  \
# 0                   Indonesia
# 1  Jakarta Pusat, DKI Jakarta
# 2                     Jakarta
# 3                         NaN
# 4                   Indonesia
#
#                                  retweet_description retweet_verified  \
# 0  Official Account of the Ministry of Tourism an...             True
# 1  Official Twitter Kementerian Sekretariat Negar...             True
# 2  Akun Twitter resmi Presiden Republik Indonesia...             True
# 3                                                NaN              NaN
# 4  Official Account of the Ministry of Tourism an...             True
#
#   place_url place_name place_full_name place_type country country_code  \
# 0       NaN        NaN             NaN        NaN     NaN          NaN
# 1       NaN        NaN             NaN        NaN     NaN          NaN
# 2       NaN        NaN             NaN        NaN     NaN          NaN
# 3       NaN        NaN             NaN        NaN     NaN          NaN
# 4       NaN        NaN             NaN        NaN     NaN          NaN
#
#   geo_coords coords_coords                        bbox_coords  \
# 0  c(NA, NA)     c(NA, NA)  c(NA, NA, NA, NA, NA, NA, NA, NA)
# 1  c(NA, NA)     c(NA, NA)  c(NA, NA, NA, NA, NA, NA, NA, NA)
# 2  c(NA, NA)     c(NA, NA)  c(NA, NA, NA, NA, NA, NA, NA, NA)
# 3  c(NA, NA)     c(NA, NA)  c(NA, NA, NA, NA, NA, NA, NA, NA)
# 4  c(NA, NA)     c(NA, NA)  c(NA, NA, NA, NA, NA, NA, NA, NA)
#
#                                           status_url  \
# 0  https://twitter.com/IndonesiaHanoi/status/1295...
# 1  https://twitter.com/IndonesiaHanoi/status/1295...
# 2  https://twitter.com/IndonesiaHanoi/status/1295...
# 3  https://twitter.com/IndonesiaHanoi/status/1295...
# 4  https://twitter.com/IndonesiaHanoi/status/1294...
#
#                                 name         location  \
# 0  The Embassy of Indonesia in Hanoi  50 Ngo Quyen St
# 1  The Embassy of Indonesia in Hanoi  50 Ngo Quyen St
# 2  The Embassy of Indonesia in Hanoi  50 Ngo Quyen St
# 3  The Embassy of Indonesia in Hanoi  50 Ngo Quyen St
# 4  The Embassy of Indonesia in Hanoi  50 Ngo Quyen St
#
#                                          description                      url  \
# 0  Kedutaan Besar Republik Indonesia di Hanoi, Vi...  https://t.co/d9B5wspn5q
# 1  Kedutaan Besar Republik Indonesia di Hanoi, Vi...  https://t.co/d9B5wspn5q
# 2  Kedutaan Besar Republik Indonesia di Hanoi, Vi...  https://t.co/d9B5wspn5q
# 3  Kedutaan Besar Republik Indonesia di Hanoi, Vi...  https://t.co/d9B5wspn5q
# 4  Kedutaan Besar Republik Indonesia di Hanoi, Vi...  https://t.co/d9B5wspn5q
#
#    protected  followers_count  friends_count  listed_count  statuses_count  \
# 0      False             7314            328            17            4022
# 1      False             7314            328            17            4022
# 2      False             7314            328            17            4022
# 3      False             7314            328            17            4022
# 4      False             7314            328            17            4022
#
#    favourites_count   account_created_at  verified              profile_url  \
# 0              1218  2015-08-13 08:48:42     False  https://t.co/d9B5wspn5q
# 1              1218  2015-08-13 08:48:42     False  https://t.co/d9B5wspn5q
# 2              1218  2015-08-13 08:48:42     False  https://t.co/d9B5wspn5q
# 3              1218  2015-08-13 08:48:42     False  https://t.co/d9B5wspn5q
# 4              1218  2015-08-13 08:48:42     False  https://t.co/d9B5wspn5q
#
#        profile_expanded_url  account_lang  \
# 0  http://kemlu.go.id/hanoi           NaN
# 1  http://kemlu.go.id/hanoi           NaN
# 2  http://kemlu.go.id/hanoi           NaN
# 3  http://kemlu.go.id/hanoi           NaN
# 4  http://kemlu.go.id/hanoi           NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/33141722...
# 1  https://pbs.twimg.com/profile_banners/33141722...
# 2  https://pbs.twimg.com/profile_banners/33141722...
# 3  https://pbs.twimg.com/profile_banners/33141722...
# 4  https://pbs.twimg.com/profile_banners/33141722...
#
#                              profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme1/bg.png
# 1  http://abs.twimg.com/images/themes/theme1/bg.png
# 2  http://abs.twimg.com/images/themes/theme1/bg.png
# 3  http://abs.twimg.com/images/themes/theme1/bg.png
# 4  http://abs.twimg.com/images/themes/theme1/bg.png
#
#                                    profile_image_url             filename
# 0  http://pbs.twimg.com/profile_images/1224303258...  Gabungan\data_1.csv
# 1  http://pbs.twimg.com/profile_images/1224303258...  Gabungan\data_1.csv
# 2  http://pbs.twimg.com/profile_images/1224303258...  Gabungan\data_1.csv
# 3  http://pbs.twimg.com/profile_images/1224303258...  Gabungan\data_1.csv
# 4  http://pbs.twimg.com/profile_images/1224303258...  Gabungan\data_1.csv

# %%
# melihat kolom
df.columns
# Out:
# Index(['Unnamed: 0', 'user_id', 'status_id', 'created_at', 'screen_name',
#        'text', 'source', 'display_text_width', 'reply_to_status_id',
#        'reply_to_user_id', 'reply_to_screen_name', 'is_quote', 'is_retweet',
#        'favorite_count', 'retweet_count', 'quote_count', 'reply_count',
#        'hashtags', 'symbols', 'urls_url', 'urls_t.co', 'urls_expanded_url',
#        'media_url', 'media_t.co', 'media_expanded_url', 'media_type',
#        'ext_media_url', 'ext_media_t.co', 'ext_media_expanded_url',
#        'ext_media_type', 'mentions_user_id', 'mentions_screen_name', 'lang',
#        'quoted_status_id', 'quoted_text', 'quoted_created_at', 'quoted_source',
#        'quoted_favorite_count', 'quoted_retweet_count', 'quoted_user_id',
#        'quoted_screen_name', 'quoted_name', 'quoted_followers_count',
#        'quoted_friends_count', 'quoted_statuses_count', 'quoted_location',
#        'quoted_description', 'quoted_verified', 'retweet_status_id',
#        'retweet_text', 'retweet_created_at', 'retweet_source',
#        'retweet_favorite_count', 'retweet_retweet_count', 'retweet_user_id',
#        'retweet_screen_name', 'retweet_name', 'retweet_followers_count',
#        'retweet_friends_count', 'retweet_statuses_count', 'retweet_location',
#        'retweet_description', 'retweet_verified', 'place_url', 'place_name',
#        'place_full_name', 'place_type', 'country', 'country_code',
#        'geo_coords', 'coords_coords', 'bbox_coords', 'status_url', 'name',
#        'location', 'description', 'url', 'protected', 'followers_count',
#        'friends_count', 'listed_count', 'statuses_count', 'favourites_count',
#        'account_created_at', 'verified', 'profile_url', 'profile_expanded_url',
#        'account_lang', 'profile_banner_url', 'profile_background_url',
#        'profile_image_url', 'filename'],
#       dtype='object')

# %%
filt = ((df["lang"]=="in") | (df["lang"]=="en")) & (df["retweet_count"]>=1)
df = df.loc[filt][["user_id","screen_name","created_at","text","is_retweet", "is_quote","favorite_count","retweet_count","lang"]].reset_index()
df.drop(columns="index", inplace=True)

# %%
df.head()
# Out:
#       user_id     screen_name           created_at  \
# 0  3314172242  IndonesiaHanoi  2020-08-18 06:58:23
# 1  3314172242  IndonesiaHanoi  2020-08-17 06:31:36
# 2  3314172242  IndonesiaHanoi  2020-08-17 05:45:16
# 3  3314172242  IndonesiaHanoi  2020-08-16 13:20:19
# 4  3314172242  IndonesiaHanoi  2020-08-16 11:21:59
#
#                                                 text  is_retweet  is_quote  \
# 0  Before the COVID-19 pandemic, Indonesians used...        True     False
# 1  Presiden Jokowi Berbaju Adat NTT Saat Pimpin U...        True     False
# 2  Kita menikmati arti kemerdekaan, karena kita m...        True     False
# 3  Get an adrenaline rush! Plunge into the mesmer...        True     False
# 4  Broken Beach in Nusa Penida offers an extraord...        True     False
#
#    favorite_count  retweet_count lang
# 0               0              7   en
# 1               0             26   in
# 2               0           8592   in
# 3               0            113   en
# 4               0             56   en

# %%
# membuat kolom baru "kbri_retweet"
df["kbri_retweet"] = df["is_retweet"].map({True:1, False:0})
df["kbri_quote"] = df["is_quote"].map({True:1, False: 0})
df["kbri_rt_like"] = df["kbri_retweet"]+df["kbri_quote"]
df["jumlah_rt_like"] = df["retweet_count"] + df["favorite_count"]
df["netizen_rt_like"] = df["jumlah_rt_like"]-df["kbri_rt_like"]

df.drop(columns=["kbri_retweet", "kbri_quote", "is_retweet", "is_quote", "favorite_count", "retweet_count"], inplace=True)
df["text"] = df["text"].str.lower()

# %%
df.head()
# Out:
#       user_id     screen_name           created_at  \
# 0  3314172242  IndonesiaHanoi  2020-08-18 06:58:23
# 1  3314172242  IndonesiaHanoi  2020-08-17 06:31:36
# 2  3314172242  IndonesiaHanoi  2020-08-17 05:45:16
# 3  3314172242  IndonesiaHanoi  2020-08-16 13:20:19
# 4  3314172242  IndonesiaHanoi  2020-08-16 11:21:59
#
#                                                 text lang  kbri_rt_like  \
# 0  before the covid-19 pandemic, indonesians used...   en             1
# 1  presiden jokowi berbaju adat ntt saat pimpin u...   in             1
# 2  kita menikmati arti kemerdekaan, karena kita m...   in             1
# 3  get an adrenaline rush! plunge into the mesmer...   en             1
# 4  broken beach in nusa penida offers an extraord...   en             1
#
#    jumlah_rt_like  netizen_rt_like
# 0               7                6
# 1              26               25
# 2            8592             8591
# 3             113              112
# 4              56               55

# %%
df.shape
# Out:
# (59892, 8)

# %%
def Klasifikasi(mode):
    a = (df["text"].str.contains("wni")) | (df["text"].str.contains("dokumen")) | (df["text"].str.contains("#negaramelindungi")) | (df["text"].str.contains("#covid19")) | (df["text"].str.contains("#covid")) | (df["text"].str.contains("#corona"))
    b = (df["text"].str.contains("hubungan diplomatik")) | (df["text"].str.contains("hubungan bilateral")) | (df["text"].str.contains("kerja sama")) | (df["text"].str.contains("#inidiplomasi")) | (df["text"].str.contains("#sahabatkemlu")) | (df["text"].str.contains("#menluretno")) | (df["text"].str.contains("#fmmarsudi")) | (df["text"].str.contains("#rintiskemajuan")) | (df["text"].str.contains("#batikdiplomacy")) | (df["text"].str.contains("#indonesianway")) | (df["text"].str.contains("#digitaldiplomacy")) | (df["text"].str.contains("#diplomasiKuliner"))
    c = (df["text"].str.contains("un / united nation")) | (df["text"].str.contains("asean")) | (df["text"].str.contains("kerjasama multilateral")) | (df["text"].str.contains("rohingya")) | (df["text"].str.contains("palestina")) | (df["text"].str.contains("suriah")) | (df["text"].str.contains("irak")) | (df["text"].str.contains("isis")) | (df["text"].str.contains("#indonesiauntukdunia")) | (df["text"].str.contains("#counterterrorism")) | (df["text"].str.contains("#diplomacyforpeaceandprosperity"))
    d = (df["text"].str.contains("papua")) | (df["text"].str.contains("sawit")) | (df["text"].str.contains("perbatasan")) | (df["text"].str.contains("demokrasi indonesia")) | (df["text"].str.contains("#balidemocracyforum"))
    
    if mode == "A":
        filt = a
    elif mode == "B":
        filt = b
    elif mode == "C":
        filt = c
    elif mode == "D":
        filt = d
    elif mode == "Total":
        filt = (a | b | c | d)
        
    return df.loc[filt]


def Percent_to_Binning(mode):
    # bins = 0-49%, 50-69%, 70-84%, 85-100%
    bins = [0, 49, 69, 84, 100]
    
    # nama label binning
    labels_name = ["Ineffective", "Adequate", "Moderately Effective", "Effetive"]
    
    hasil_clf = Klasifikasi(mode)
    
    if mode == "A":
        hasil_clf["klasifikasi"] = "A"
    elif mode == "B":
        hasil_clf["klasifikasi"] = "B"
    elif mode == "C":
        hasil_clf["klasifikasi"] = "C"
    elif mode == "D":
        hasil_clf["klasifikasi"] = "D"
    
    # tambahkan kolom "percent" yang berisi percent jumlah retweet dan like terhadap jumlah maksimal
    hasil_clf["percent"] = hasil_clf["jumlah_rt_like"] / hasil_clf["jumlah_rt_like"].max() * 100
    
    # tambahkan kolom "scoring_to_clf" yang berisi binning dari data percent
    hasil_clf["scoring_to_clf"] = pd.cut(hasil_clf["percent"], bins, labels=labels_name)
    
    return hasil_clf

# %%
# df baru adalah semua data yang masuk klasifikasi
df = Klasifikasi("Total")
df.head()
# Out:
#        user_id     screen_name           created_at  \
# 9   3314172242  IndonesiaHanoi  2020-08-13 00:58:01
# 11  3314172242  IndonesiaHanoi  2020-08-11 09:04:11
# 15  3314172242  IndonesiaHanoi  2020-08-10 01:31:04
# 16  3314172242  IndonesiaHanoi  2020-08-09 08:44:41
# 17  3314172242  IndonesiaHanoi  2020-08-07 04:37:55
#
#                                                  text lang  kbri_rt_like  \
# 9   “history has taught us that crisis may also cr...   en             1
# 11  @indonesiahanoi will organize an online sessio...   en             0
# 15  #happyaseanday2020 : asean foreign minister re...   en             1
# 16  telkom university akan menyelenggarakan webina...   in             0
# 17  on 7/8, ambassador ibnu hadi attended the asea...   en             0
#
#     jumlah_rt_like  netizen_rt_like
# 9               41               40
# 11               2                2
# 15              33               32
# 16               3                3
# 17               8                8

# %%
df.shape
# Out:
# (22621, 8)

# %%
print(f"Rt Like kbri: {df['kbri_rt_like'].sum()}\nRt Like netizen: {df['netizen_rt_like'].sum()}")
# Out:
# Rt Like kbri: 15380
# Rt Like netizen: 1943306
